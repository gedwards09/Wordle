# %%
import numpy as np
import pandas as pd
import time
from WordleFunctions import wordle, hardModeFilter, cypher, entropy, nextWord

# %%
five = pd.concat([
    pd.read_csv("wordle-answers-alphabetical.txt",header=None,names=["word"]),
    pd.read_csv("wordle-allowed-guesses.txt",header=None,names=["word"])],axis=0,ignore_index=True
)
answers = pd.read_csv("wordle-answers-alphabetical.txt",header=None,names=["word"])

# %%
startTime=time.time()
answers = pd.read_csv("wordle-answers-alphabetical.txt",header=None,names=["word"])
file=open('wordle-guesses.txt','w')
hardMode=True
distribution=[0 for i in range(7)]
num=0
for answer in answers.word:
    dfPossibleAnswers=answers
    dfGuesses=five
    guess="soare"
    file.write(guess) # write initial guess to file
    ct=1 # initialize guess count at 1
    while guess!=answer:
        response=wordle(answer,guess)
        dfPossibleAnswers=dfPossibleAnswers[cypher(dfPossibleAnswers.word,guess)==response] #filter possible words
        if hardMode:
            dfGuesses=dfGuesses[dfGuesses.word.apply(lambda x: hardModeFilter(x,guess,response))]
        if dfPossibleAnswers.shape[0]==1:
            guess=dfPossibleAnswers.word.iloc[0]
        else:
            guess=nextWord(dfPossibleAnswers.word,dfGuesses.word)
        file.write(',')
        file.write(guess) # write next guess to file, stop when guess==answer
        ct+=1
    file.write('\n')
    if ct>6:
        print("One failed")
        distribution[6]+=1
    else:
        distribution[ct-1]+=1
    num+=1
    if num%100==0:
        print("Finished",num,"words in",round((time.time() - startTime)/60,2),"minutes")
        tot=0
        for i in range(len(distribution)):
            tot+=(i+1)*distribution[i]
        mean=tot/num
        print("Average: ",round(mean,4))
file.close()
print(distribution)
# Out:
# Finished 100 words in 1.2 minutes
# Average:  3.5
# Finished 200 words in 3.02 minutes
# Average:  3.47
# Finished 300 words in 5.21 minutes
# Average:  3.4833
# Finished 400 words in 8.19 minutes
# Average:  3.4675
# Finished 500 words in 9.87 minutes
# Average:  3.514
# Finished 600 words in 12.26 minutes
# Average:  3.5167
# Finished 700 words in 14.61 minutes
# Average:  3.5271
# Finished 800 words in 17.62 minutes
# Average:  3.5525
# Finished 900 words in 19.58 minutes
# Average:  3.5944
# Finished 1000 words in 21.65 minutes
# Average:  3.625
# One failed
# One failed
# Finished 1100 words in 25.17 minutes
# Average:  3.6464
# Finished 1200 words in 28.02 minutes
# Average:  3.6617
# One failed
# Finished 1300 words in 30.37 minutes
# Average:  3.6785
# One failed
# Finished 1400 words in 31.91 minutes
# Average:  3.6729
# Finished 1500 words in 34.97 minutes
# Average:  3.6873
# Finished 1600 words in 36.39 minutes
# Average:  3.6956
# Finished 1700 words in 36.64 minutes
# Average:  3.6724
# Finished 1800 words in 36.98 minutes
# Average:  3.6661
# Finished 1900 words in 37.18 minutes
# Average:  3.6653
# One failed
# Finished 2000 words in 37.51 minutes
# Average:  3.6785
# Finished 2100 words in 39.65 minutes
# Average:  3.6733
# One failed
# Finished 2200 words in 42.25 minutes
# Average:  3.6768
# One failed
# One failed
# Finished 2300 words in 45.07 minutes
# Average:  3.6926
# [0, 71, 887, 1094, 217, 38, 8]
